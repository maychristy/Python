# %% [markdown]
# **NIM : D121201050**
#
# **Nama : Maylinda Eka Christy**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import tensorflow as tf

filecsv = pd.read_csv('vgsaless.csv')

# %%
filecsv
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                               NaN      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
filecsv.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %% [markdown]
# **Mengahapus Data**

# %%
filecsv.dropna(subset=['Name'], inplace= True)

# %% [markdown]
# **Categorical Value**

# %%
#year

filecsv['Year'].unique()
year_mode = filecsv.Year.mode()[0]
print('mode for year', year_mode)
filecsv.Year.fillna(year_mode, inplace=True)
# Out:
# mode for year 2009.0

# %%
#publish

filecsv['Publisher'].unique()
publisher_mode = filecsv.Publisher.mode()[0]
print('mode of Publisher: ', publisher_mode)
filecsv.Publisher.fillna(publisher_mode, inplace=True)
# Out:
# mode of Publisher:  Electronic Arts

# %% [markdown]
# **Numerical Value**

# %%
mean_JPSales = filecsv.JP_Sales.mean()
print('mean of Jp Sales: ', mean_JPSales)
filecsv.JP_Sales.fillna(mean_JPSales, inplace=True)
# Out:
# mean of Jp Sales:  0.07645130183220829

# %%
print(filecsv.isna().sum())
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
filecsv['Name'].unique()
# Out:
# array(['Wii Sports', 'Super Mario Bros.', 'Mario Kart Wii', ...,
#        'Plushees', 'Woody Woodpecker in Crazy Castle 5', 'Know How 2'],
#       dtype=object)

# %%
filecsv['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
filecsv['Year'].unique()
# Out:
# array([2006., 1985., 2008., 1996., 1989., 2009., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2003., 1986., 2000., 1995., 2016., 1991., 1981., 1987., 1980.,
#        1983., 2020., 2017.])

# %%
filecsv['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle',
#        'Shooter', 'Simulation', 'Misc', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
filecsv['Publisher'].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment',
#        'Sony Computer Entertainment Europe', 'Square Enix', 'LucasArts',
#        'Virgin Interactive', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        'Majesco Entertainment', 'Codemasters', 'Red Orb', 'Level 5',
#        'Arena Entertainment', 'Midway Games', 'JVC', 'Deep Silver',
#        '989 Studios', 'NCSoft', 'UEP Systems', 'Parker Bros.', 'Maxis',
# ...

# %%
filecsv.groupby('Name')['Rank'].sum()#
# Out:
# Name
# '98 Koshien                                 4756
# .hack//G.U. Vol.1//Rebirth                  8359
# .hack//G.U. Vol.2//Reminisce                7109
# .hack//G.U. Vol.2//Reminisce (jp sales)     8604
# .hack//G.U. Vol.3//Redemption               8306
#                                            ...
# thinkSMART: Chess for Kids                 16417
# uDraw Studio                                 628
# uDraw Studio: Instant Artist               23363
# wwe Smackdown vs. Raw 2006                   471
# ¡Shin Chan Flipa en colores!                9137
# Name: Rank, Length: 11491, dtype: int64

# %%
filecsv['Publisher'] = pd.factorize(filecsv['Publisher'])[0]
filecsv
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# 5          6                                            Tetris       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
filecsv['Genre'] = pd.factorize(filecsv['Genre'])[0]
filecsv
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# 5          6                                            Tetris       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
filecsv['Platform'] = pd.factorize(filecsv['Platform'])[0]
filecsv
# Out:
#         Rank                                              Name  Platform  \
# 0          1                                        Wii Sports         0
# 1          2                                 Super Mario Bros.         1
# 2          3                                    Mario Kart Wii         0
# 4          5                          Pokemon Red/Pokemon Blue         2
# 5          6                                            Tetris         2
# ...      ...                                               ...       ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5         8
# 16594  16597                     Men in Black II: Alien Escape        18
# 16595  16598  SCORE International Baja 1000: The Official Game         6
# 16596  16599                                        Know How 2         3
# 16597  16600                                  Spirits & Spells         8
#
#          Year  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
drop_name= filecsv.drop('Name', axis=1, inplace=True)

# %%
filecsv.dtypes
# Out:
# Rank              int64
# Platform          int64
# Year            float64
# Genre             int64
# Publisher         int64
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
correlation = filecsv.corr(method='pearson')
correlation
sb.set (rc = {'figure.figsize':(9, 8)})
sb.heatmap(correlation, xticklabels=correlation.columns,yticklabels=correlation.columns, cmap='RdBu_r', annot=True, linewidths=0.2)
# Out:
# <AxesSubplot: >

# %%
sb.pairplot(filecsv, kind='reg')

# %%
filecsv
# Out:
#         Rank  Platform    Year  Genre  Publisher  NA_Sales  EU_Sales  \
# 0          1         0  2006.0      0          0     41.49     29.02
# 1          2         1  1985.0      1          0     29.08      3.58
# 2          3         0  2008.0      2          0     15.85     12.88
# 4          5         2  1996.0      3          0     11.27      8.89
# 5          6         2  1989.0      4          0     23.20      2.26
# ...      ...       ...     ...    ...        ...       ...       ...
# 16593  16596         8  2002.0      1        187      0.01      0.00
# 16594  16597        18  2003.0      5         51      0.01      0.00
# 16595  16598         6  2008.0      2          4      0.00      0.00
# 16596  16599         3  2010.0      4        507      0.00      0.01
# 16597  16600         8  2003.0      1        170      0.01      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 0      3.770000         8.46         82.74
# 1      6.810000         0.77         40.24
# ...

# %% [markdown]
# ### Melakukan drop pada kolom yang tidak memiliki korelasi

# %%
filecsv.drop(['Rank', 'Platform', 'Year', 'Genre', 'Publisher'], axis=1, inplace=True)

# %%
filecsv.head()
# Out:
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02  3.770000         8.46         82.74
# 1     29.08      3.58  6.810000         0.77         40.24
# 2     15.85     12.88  3.790000         3.31         35.82
# 4     11.27      8.89  0.076451         1.00         31.37
# 5     23.20      2.26  4.220000         0.58         30.26

# %% [markdown]
# ### Pemisahan Variabel independen dan dependen
# pada kasus ini variabel independen adalah Global_Sales yang akan diletakkan pada varibel y dan variabel dependennya akan di letakkan pada variabel X

# %%
X = filecsv.drop(columns='Global_Sales')
y = filecsv['Global_Sales']
y.head()
# Out:
# 0    82.74
# 1    40.24
# 2    35.82
# 4    31.37
# 5    30.26
# Name: Global_Sales, dtype: float64

# %%
X.head()
# Out:
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0     41.49     29.02  3.770000         8.46
# 1     29.08      3.58  6.810000         0.77
# 2     15.85     12.88  3.790000         3.31
# 4     11.27      8.89  0.076451         1.00
# 5     23.20      2.26  4.220000         0.58

# %% [markdown]
# ### Membangun model dengan Statsmodel
#
# setelah memisahkan variabelnya. kita akan membangun model dengan statsmodel
#
# kenapa statsmodel? "As its name implies, statsmodels is a Python library built specifically for statistics. Statsmodels is built on top of NumPy, SciPy, and matplotlib, but it contains more advanced functions for statistical testing and modeling that you won't find in numerical libraries like NumPy or SciPy."
#
# lalu membuat model lm dengam OLS →  Ordinary Least Squares
#
# OLS -> merupakan salah satu metode dalam analisis regresi berganda untuk mengetahui pengaruh variabel bebas terhadap variabel tak bebas. Metode Ordinary Least Square akan menghasilkan estimasi yang terbaik dibanding dengan metode lain jika semua asumsi klasik terpenuhi. Sebaliknya, jika asumsi klasik tidak terpenuhi akan menghasilkan estimator yang jelek.
#
# selain OLS ada juga ada metode WLS dan GLS.
#
# WLS → Weighted Least Squares
#
# GLS → Generalized Least Squares

# %%
import statsmodels.api as sm
lm = sm.OLS(y, X)
model = lm.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:           Global_Sales   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                          1.407e+06
# Date:                Fri, 21 Apr 2023   Prob (F-statistic):                        0.00
# Time:                        01:42:04   Log-Likelihood:                          16927.
# No. Observations:               16596   AIC:                                 -3.385e+04
# Df Residuals:                   16592   BIC:                                 -3.382e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split
#split data menjadi training dan testing dengan perbandingan 80:20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

#Cek shape dari data training dan testing
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (13276, 4)
# (13276,)
# (3320, 4)
# (3320,)

# %% [markdown]
# ### Membangun model dengan scikit learn

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('intercept : ', lm.intercept_)
print('koefisien : ', lm.coef_)
# Out:
# intercept :  -0.0034789131293816444
# koefisien :  [1.00396162 1.06202027 0.96484352 0.95116092]

# %%
coef_dict = {
    'features': X.columns,
    'coef_value':lm.coef_
}
coef = pd.DataFrame(coef_dict, columns=['features', 'coef_value'])
coef
# Out:
#       features  coef_value
# 0     NA_Sales    1.003962
# 1     EU_Sales    1.062020
# 2     JP_Sales    0.964844
# 3  Other_Sales    0.951161

# %% [markdown]
# dari nilai m dan b diatas, jika dimasukan ke dalam rumus menjadi:
#
# Y = 1.003962x1 + 1.062020x2 + 0.964844x3 + 0.951161x4 -0.0034789131293816444
#
# inilah model yang akan diterapkan untuk prediksi selanjutnya

# %% [markdown]
# ## Prediksi Model

# %%
y_pred = lm.predict(X_test)

# %%
a = lm.score(X_test, y_test)

# %%
print(f'accuracy: {a*100:.2f}%')
# Out:
# accuracy: 99.97%

# %% [markdown]
# model ini mendapatkan akurasi sebesar 99.97%

# %%
sb.distplot((y_test-y_pred),bins=100);
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_644\1882133506.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot((y_test-y_pred),bins=100);

# %% [markdown]
# dari gambar histogram di atas dapat dilihat bahwa data tersebu terdistribusi secara normal
#
# Histogram Residual dapat digunakan untuk memeriksa apakah varian terdistribusi secara normal. Histogram berbentuk lonceng simetris yang terdistribusi merata di sekitar nol menunjukkan bahwa asumsi normalitas kemungkinan besar benar.

# %% [markdown]
# ### Evaluasi performa model
#
# MAE(Mean Absolute Error) → menghitung berapa rata-rata kesalahan absolut dalam prediksi. Semakin kecil nilai MAE, semakin baik kualitas model tersebut.
#
# MSE (Mean Squared Error) → menghitung rata-rata dari selisih kuadrat antara nilai prediksi dan nilai aktual. Semakin kecil nilai MSE, semakin baik kualitas model tersebut
#
# RMSE → RMSE menghitung rata-rata dari selisih kuadrat antara nilai prediksi dan nilai aktual kemudian diambil akar kuadratnya. Semakin kecil nilai RMSE, semakin baik kualitas model tersebut.

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 0.011082956740106018
# MSE: 0.0010994954423926408
# RMSE: 0.03315864053897024
